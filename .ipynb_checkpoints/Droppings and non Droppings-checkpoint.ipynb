# %%
from ultralytics import YOLO

# %%
#LOADING THE YOLOV5-TINY

model = YOLO("yolov5su.pt")

# %%
 results = model("dataset/train/images", save_txt=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/3627 /home/takudzwa/Documents/Projects/broiler_disease/detection/dataset/train/images/cocci.0.jpg: 288x640 (no detections), 227.3ms
# image 2/3627 /home/takudzwa/Documents/Projects/broiler_disease/detection/dataset/train/images/cocci.1.jpg: 640x480 (no detections), 273.2ms
# image 3/3627 /home/takudzwa/Documents/Projects/broiler_disease/detection/dataset/train/images/cocci.10.jpg: 288x640 1 pizza, 156.9ms
# ...

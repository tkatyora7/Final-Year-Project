# %%
# 1 LOAD MODULES 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import tensorflow as tf
from collections import Counter
import numpy as np
from collections import Counter
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, GlobalAveragePooling2D ,Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping


print('modules loaded')
# Out:
# model loaded

# %%
# 1 PREPROCESS THE DATA AND DATA  AUGEMENTATION

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['TF_CPP_MIN_VLOG_LEVEL'] = '3'


# Data augmentation setup
datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=False,
    brightness_range=(0.7, 1.3),
    shear_range=0.2,
    fill_mode='nearest',
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    "../FOMO/ESP_32/train",
    target_size=(96, 96),
    batch_size=32,
    class_mode="categorical",
    subset="training"
)

val_data = datagen.flow_from_directory(
    "../FOMO/ESP_32/train",
    target_size=(96, 96),
    batch_size=32,
    class_mode="categorical",
    subset="validation"
)
# Out:
# Found 699 images belonging to 4 classes.
# Found 173 images belonging to 4 classes.

# %%
print(train_data.class_indices)
labels = train_data.classes  
class_counts = Counter(labels)
index_to_class = {v: k for k, v in train_data.class_indices.items()}

for class_index, count in class_counts.items():
    print(f"{index_to_class[class_index]}: {count} images")
# Out:
# {'cocii': 0, 'healthy': 1, 'ncd': 2, 'others': 3}
# cocii: 208 images
# healthy: 85 images
# ncd: 210 images
# others: 196 images

# %%
# MODEL FOR THE CLOUD
# 3 LOADING A PRETRAINED MODEL
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False  

#OUR OWN TOP LAYER
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(4, activation="softmax")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=["accuracy"]
)

model.summary()
# Out:
# 2025-06-09 22:54:01.389848: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_96             │ (None, 3, 3, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,422,468 (9.24 MB)
#  Trainable params: 164,484 (642.52 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
# MODEL FOR THE EDGE DEVICE ESP32 CAM

num_classes = 4
esp32_model = tf.keras.Sequential([
    
   tf.keras.layers.Input(shape=(96, 96, 3))  ,

    tf.keras.layers.Conv2D(8, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(16, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.GlobalAveragePooling2D(),

    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

esp32_model.compile(
optimizer='adam',
loss='categorical_crossentropy',
metrics=['accuracy'])

esp32_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 94, 94, 8)      │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 47, 47, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 45, 45, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 22, 22, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 16)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,732 (6.77 KB)
#  Trainable params: 1,732 (6.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# TRAINING THE MODELS

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, min_delta=0.001,)


history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=30,  
    callbacks=[early_stopping]
)

esp32_history = esp32_model.fit(
    train_data,
    validation_data=val_data,
    epochs=30,  
    callbacks=[early_stopping])
# Out:
# /home/takudzwa/.local/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.5216 - loss: 3.6640 - val_accuracy: 0.6821 - val_loss: 2.8584
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.7807 - loss: 2.5957 - val_accuracy: 0.6590 - val_loss: 2.5158
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.8470 - loss: 2.1714 - val_accuracy: 0.7283 - val_loss: 2.1447
# Epoch 4/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8188 - loss: 1.9352 - val_accuracy: 0.8150 - val_loss: 1.8614
# Epoch 5/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8636 - loss: 1.6968 - val_accuracy: 0.7630 - val_loss: 1.6971
# Epoch 6/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8592 - loss: 1.5480 - val_accuracy: 0.8208 - val_loss: 1.5334
# Epoch 7/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8543 - loss: 1.4468 - val_accuracy: 0.8208 - val_loss: 1.4293
# Epoch 8/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8883 - loss: 1.3105 - val_accuracy: 0.7919 - val_loss: 1.3864
# Epoch 9/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8886 - loss: 1.2301 - val_accuracy: 0.7746 - val_loss: 1.3694
# Epoch 10/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8803 - loss: 1.1538 - val_accuracy: 0.8324 - val_loss: 1.1758
# Epoch 11/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9125 - loss: 1.0487 - val_accuracy: 0.8671 - val_loss: 1.1141
# Epoch 12/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.9078 - loss: 1.0551 - val_accuracy: 0.7919 - val_loss: 1.1479
# Epoch 13/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.8979 - loss: 0.9838 - val_accuracy: 0.8613 - val_loss: 1.0406
# Epoch 14/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8773 - loss: 0.9873 - val_accuracy: 0.8555 - val_loss: 1.0524
# Epoch 15/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.8924 - loss: 0.9404 - val_accuracy: 0.8497 - val_loss: 0.9722
# Epoch 16/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.8953 - loss: 0.9033 - val_accuracy: 0.8266 - val_loss: 0.9609
# Epoch 17/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.8955 - loss: 0.8777 - val_accuracy: 0.8092 - val_loss: 0.9838
# Epoch 18/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.8932 - loss: 0.8513 - val_accuracy: 0.8497 - val_loss: 0.9466
# Epoch 19/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9033 - loss: 0.8269 - val_accuracy: 0.8324 - val_loss: 0.9256
# Epoch 20/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9206 - loss: 0.7817 - val_accuracy: 0.8208 - val_loss: 0.9257
# Epoch 21/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.9085 - loss: 0.7705 - val_accuracy: 0.7977 - val_loss: 0.9138
# Epoch 22/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9312 - loss: 0.7486 - val_accuracy: 0.8439 - val_loss: 0.8632
# Epoch 23/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.8911 - loss: 0.7877 - val_accuracy: 0.7630 - val_loss: 1.0282
# Epoch 24/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9063 - loss: 0.7709 - val_accuracy: 0.8439 - val_loss: 0.8757
# Epoch 25/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.8937 - loss: 0.7790 - val_accuracy: 0.8497 - val_loss: 0.8390
# Epoch 26/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9166 - loss: 0.7302 - val_accuracy: 0.8092 - val_loss: 0.8910
# Epoch 27/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9176 - loss: 0.7202 - val_accuracy: 0.8382 - val_loss: 0.8426
# Epoch 28/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9100 - loss: 0.7511 - val_accuracy: 0.8382 - val_loss: 0.8409
# Epoch 29/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9145 - loss: 0.7213 - val_accuracy: 0.8150 - val_loss: 0.8442
# Epoch 30/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.9046 - loss: 0.7287 - val_accuracy: 0.8382 - val_loss: 0.8162
# Epoch 1/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.3087 - loss: 1.3792 - val_accuracy: 0.3006 - val_loss: 1.3535
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.3103 - loss: 1.3494 - val_accuracy: 0.3006 - val_loss: 1.3439
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.2967 - loss: 1.3288 - val_accuracy: 0.2775 - val_loss: 1.3453
# Epoch 4/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.3069 - loss: 1.2913 - val_accuracy: 0.3873 - val_loss: 1.3247
# Epoch 5/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.4228 - loss: 1.2776 - val_accuracy: 0.2717 - val_loss: 1.3308
# Epoch 6/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.4151 - loss: 1.2159 - val_accuracy: 0.3064 - val_loss: 1.3341
# Epoch 7/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.4706 - loss: 1.1768 - val_accuracy: 0.3642 - val_loss: 1.3007
# Epoch 8/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.4860 - loss: 1.1426 - val_accuracy: 0.4393 - val_loss: 1.2856
# Epoch 9/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.4828 - loss: 1.1131 - val_accuracy: 0.3179 - val_loss: 1.3479
# Epoch 10/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.5380 - loss: 1.1068 - val_accuracy: 0.4104 - val_loss: 1.3020
# Epoch 11/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.5834 - loss: 1.0602 - val_accuracy: 0.4740 - val_loss: 1.2740
# Epoch 12/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.5456 - loss: 1.0404 - val_accuracy: 0.3873 - val_loss: 1.2951
# Epoch 13/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.5839 - loss: 1.0033 - val_accuracy: 0.4277 - val_loss: 1.3012
# Epoch 14/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.5392 - loss: 1.0500 - val_accuracy: 0.4624 - val_loss: 1.2803
# Epoch 15/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.6233 - loss: 0.9719 - val_accuracy: 0.4566 - val_loss: 1.2947
# Epoch 16/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.5826 - loss: 0.9992 - val_accuracy: 0.4740 - val_loss: 1.2807

# %%
#VALIDATION FO THE MODEL
# Evaluate FOMO model on validation data
val_images, val_labels = next(val_data) 
evaluation = model.evaluate(val_images, val_labels)
print(f"Cloud Model Loss: {evaluation[0]}")
print(f" Cloud Model Accuracy: {evaluation[1]}")

evaluation =esp32_model.evaluate(val_images, val_labels)
print(f"ESP32 Model Loss: {evaluation[0]}")
print(f"ESP32 Model Accuracy: {evaluation[1]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8438 - loss: 0.8229
# Cloud Model Loss: 0.8229444622993469
#  Cloud Model Accuracy: 0.84375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5000 - loss: 1.3039
# ESP32 Model Loss: 1.303917646408081
# ESP32 Model Accuracy: 0.5

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss =history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt



acc = esp32_history.history['accuracy']
val_acc = esp32_history.history['val_accuracy']
loss = esp32_history.history['loss']
val_loss =esp32_history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
edge_model =esp32_model.save("broiler_model_edge.keras")
cloud_model =model.save("broiler_model_cloud.keras")

# %%
django_converter = tf.lite.TFLiteConverter.from_keras_model(model)
django_tflite_model = django_converter.convert()
django_path = '/home/takudzwa/Documents/Projects/broiler_disease/final_year_broiler/fomo_model.tflite'
with open(django_path, 'wb') as f:
    f.write(django_tflite_model)
print(f"Django model saved to: {django_path}")
print(f"Django model size: {len(django_tflite_model)/1024:.2f} KB")

#EDGE CONVERTOR
edge_converter = tf.lite.TFLiteConverter.from_keras_model(model)
edge_tflite_model = edge_converter.convert()
edge_path = '/home/takudzwa/Documents/Projects/broiler_disease/final_year_broiler/fomo_model_edge.tflite'
with open(edge_path, 'wb') as f:
    f.write(edge_tflite_model)
print(f"Django model saved to: {edge_path}")
print(f"Django model size: {len(edge_tflite_mode)/1024:.2f} KB")
